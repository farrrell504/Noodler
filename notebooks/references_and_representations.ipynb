# %% [markdown]
# [python audio guitar](https://makersportal.com/blog/2018/9/20/audio-processing-in-python-part-iii-guitar-string-theory-and-frequency-analysis)

# %% [markdown]
# [trig_idents](https://en.wikipedia.org/wiki/List_of_trigonometric_identities)

# %% [markdown]
# Use obscure trig identity you definitely remember off the top of your head:
# > $sin(a)+sin(b)= 2sin(\frac {a+b}{2})cos(\frac {a-b}{2})$

# %% [markdown]
# [wave of stretched string](https://courses.lumenlearning.com/suny-osuniversityphysics/chapter/16-3-wave-speed-on-a-stretched-string/)

# %% [markdown]
# <center><h1>Direction

# %% [markdown]
# [lumen](https://courses.lumenlearning.com/boundless-physics/chapter/wave-behavior-and-interaction/)
# says u(x,t) = f(x+ct) + g(x-ct)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fs = 100
l = 2
n = fs*l
f = 2
t = np.arange(n)/fs
x = np.sin(2*np.pi*f*t)

# %%
plt.plot(x)

# %%
plt.plot(x*2)

# %% [markdown]
# numpy sin

# %%
np.allclose(np.sin(2*np.pi),0)
